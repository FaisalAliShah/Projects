# %%
import pandas as pd

pd.set_option('display.max_columns',None)

# %%
tree_census=pd.read_csv(r"C:\Users\IceCandyman\Desktop\python\projects\2015_Street_Tree_Census_-_Tree_Data.csv")
tree_census.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple    None   None
# 1                   Quercus palustris          pin oak    None   None
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2   None
# 3  Gleditsia triacanthos var. inermis      honeylocust    None   None
# 4                     Tilia americana  American linden    None   None
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# 0  NoDamage  TreesCount Staff     None         No         No         No
# 1    Damage  TreesCount Staff   Stones        Yes         No         No
# 2    Damage         Volunteer     None         No         No         No
# 3    Damage         Volunteer   Stones        Yes         No         No
# 4    Damage         Volunteer   Stones        Yes         No         No
#
#   trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other  \
# 0         No         No         No         No        No         No
# 1         No         No         No         No        No         No
# 2         No         No         No         No        No         No
# 3         No         No         No         No        No         No
# 4         No         No         No         No        No         No
#
#              address  postcode      zip_city  community board  borocode  \
# 0  108-005 70 AVENUE     11375  Forest Hills              406         4
# 1   147-074 7 AVENUE     11357    Whitestone              407         4
# 2  390 MORGAN AVENUE     11211      Brooklyn              301         3
# 3  1027 GRAND STREET     11211      Brooklyn              301         3
# 4       603 6 STREET     11215      Brooklyn              306         3
#
#     borough  cncldist  st_assem  st_senate   nta            nta_name  boro_ct  \
# 0    Queens        29        28         16  QN17        Forest Hills  4073900
# 1    Queens        19        27         11  QN49          Whitestone  4097300
# 2  Brooklyn        34        50         18  BK90   East Williamsburg  3044900
# 3  Brooklyn        34        53         18  BK90   East Williamsburg  3044900
# 4  Brooklyn        39        44         21  BK37  Park Slope-Gowanus  3016500
#
#       state   latitude  longitude         x_sp         y_sp  council district  \
# 0  New York  40.723092 -73.844215  1027431.148  202756.7687              29.0
# 1  New York  40.794111 -73.818679  1034455.701  228644.8374              19.0
# 2  New York  40.717581 -73.936608  1001822.831  200716.8913              34.0
# 3  New York  40.713537 -73.934456  1002420.358  199244.2531              34.0
# 4  New York  40.666778 -73.975979   990913.775  182202.4260              39.0
#
#    census tract        bin           bbl
# 0         739.0  4052307.0  4.022210e+09
# 1         973.0  4101931.0  4.044750e+09
# 2         449.0  3338310.0  3.028870e+09
# 3         449.0  3338342.0  3.029250e+09
# 4         165.0  3025654.0  3.010850e+09

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset= tree_census[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward',
       'guards', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0   180683         3           0   OnCurb  Alive   Fair
# 1   200540        21           0   OnCurb  Alive   Fair
# 2   204026         3           0   OnCurb  Alive   Good
# 3   204337        10           0   OnCurb  Alive   Good
# 4   189565        21           0   OnCurb  Alive   Good
#
#                             spc_latin steward guards  sidewalk problems  \
# 0                         Acer rubrum    None   None  NoDamage     None
# 1                   Quercus palustris    None   None    Damage   Stones
# 2  Gleditsia triacanthos var. inermis    1or2   None    Damage     None
# 3  Gleditsia triacanthos var. inermis    None   None    Damage   Stones
# 4                     Tilia americana    None   None    Damage   Stones
#
#   root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0         No         No         No         No         No         No
# 1        Yes         No         No         No         No         No
# 2         No         No         No         No         No         No
# 3        Yes         No         No         No         No         No
# 4        Yes         No         No         No         No         No
#
#   brch_light brch_shoe brch_other
# 0         No        No         No
# 1         No        No         No
# 2         No        No         No
# 3         No        No         No
# 4         No        No         No

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# guards        31616
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
#        steward guards sidewalk problems root_stone root_grate root_other  \
# 37         NaN    NaN      NaN      NaN         No         No         No
# 57         NaN    NaN      NaN      NaN         No         No         No
# 196        NaN    NaN      NaN      NaN         No         No         No
# 209        NaN    NaN      NaN      NaN         No         No         No
# 239        NaN    NaN      NaN      NaN         No         No         No
# ...        ...    ...      ...      ...        ...        ...        ...
# 683693     NaN    NaN      NaN      NaN         No         No         No
# 683695     NaN    NaN      NaN      NaN         No         No         No
# 683697     NaN    NaN      NaN      NaN         No         No         No
# 683698     NaN    NaN      NaN      NaN         No         No         No
# 683699     NaN    NaN      NaN      NaN         No         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No         No        No         No
# 57             No         No         No         No        No         No
# 196            No         No         No         No        No         No
# 209            No         No         No         No        No         No
# 239            No         No         No         No        No         No
# ...           ...        ...        ...        ...       ...        ...
# 683693         No         No         No         No        No         No
# 683695         No         No         No         No        No         No
# 683697         No         No         No         No        No         No
# 683698         No         No         No         No        No         No
# 683699         No         No         No         No        No         No
#
# [31616 rows x 20 columns]

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# guards        object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'tree_id'}>,
#         <Axes: title={'center': 'tree_dbh'}>],
#        [<Axes: title={'center': 'stump_diam'}>, <Axes: >]], dtype=object)

# %%
big_trees = tree_census_subset[tree_census_subset['stump_diam']>50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6122     200925         0          52   OnCurb  Stump    NaN       NaN
# 6177     200924         0          55   OnCurb  Stump    NaN       NaN
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9872     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 645994   135904         0          65   OnCurb  Stump    NaN       NaN
# 646336   151125         0          55   OnCurb  Stump    NaN       NaN
# 649174   154188         0          65   OnCurb  Stump    NaN       NaN
# 652690   154181         0          60   OnCurb  Stump    NaN       NaN
# 653066   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        steward guards sidewalk problems root_stone root_grate root_other  \
# 6122       NaN    NaN      NaN      NaN         No         No         No
# 6177       NaN    NaN      NaN      NaN         No         No         No
# 6466       NaN    NaN      NaN      NaN         No         No         No
# 7042       NaN    NaN      NaN      NaN         No         No         No
# 9872       NaN    NaN      NaN      NaN         No         No         No
# ...        ...    ...      ...      ...        ...        ...        ...
# 645994     NaN    NaN      NaN      NaN         No         No         No
# 646336     NaN    NaN      NaN      NaN         No         No         No
# 649174     NaN    NaN      NaN      NaN         No         No         No
# 652690     NaN    NaN      NaN      NaN         No         No         No
# 653066     NaN    NaN      NaN      NaN         No         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 6122           No         No         No         No        No         No
# 6177           No         No         No         No        No         No
# 6466           No         No         No         No        No         No
# 7042           No         No         No         No        No         No
# 9872           No         No         No         No        No         No
# ...           ...        ...        ...        ...       ...        ...
# 645994         No         No         No         No        No         No
# 646336         No         No         No         No        No         No
# 649174         No         No         No         No        No         No
# 652690         No         No         No         No        No         No
# 653066         No         No         No         No        No         No
#
# [235 rows x 20 columns]

# %%
big_trees[['tree_id',"stump_diam"]].plot(kind='scatter', x='tree_id', y='stump_diam', figsize=(20,10))
# Out:
# <Axes: xlabel='tree_id', ylabel='stump_diam'>

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
stumps=tree_census_subset[tree_census_subset['status']=='Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward guards sidewalk problems root_stone root_grate root_other  \
# 37         NaN    NaN      NaN      NaN         No         No         No
# 239        NaN    NaN      NaN      NaN         No         No         No
# 641        NaN    NaN      NaN      NaN         No         No         No
# 644        NaN    NaN      NaN      NaN         No         No         No
# 646        NaN    NaN      NaN      NaN         No         No         No
# ...        ...    ...      ...      ...        ...        ...        ...
# 683348     NaN    NaN      NaN      NaN         No         No         No
# 683686     NaN    NaN      NaN      NaN         No         No         No
# 683695     NaN    NaN      NaN      NaN         No         No         No
# 683697     NaN    NaN      NaN      NaN         No         No         No
# 683699     NaN    NaN      NaN      NaN         No         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No         No        No         No
# 239            No         No         No         No        No         No
# 641            No         No         No         No        No         No
# 644            No         No         No         No        No         No
# 646            No         No         No         No        No         No
# ...           ...        ...        ...        ...       ...        ...
# 683348         No         No         No         No        No         No
# 683686         No         No         No         No        No         No
# 683695         No         No         No         No        No         No
# 683697         No         No         No         No        No         No
# 683699         No         No         No         No        No         No
#
# [17654 rows x 20 columns]

# %%
tree_probl=tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_probl
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 683783         No        No         No
# 683784         No        No         No
# 683785         No        No         No
# 683786         No        No         No
# 683787         No        No         No
#
# [683788 rows x 9 columns]

# %%
tree_probl.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %%
mask = ((tree_census_subset['status'] == 'Stump') | (tree_census_subset['status'] == 'Dead'))

# %%
tree_census_subset.loc[mask] = tree_census_subset.loc[mask].fillna('Not Applicable')

# %%
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward          guards        sidewalk  \
# 37      Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 239     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 641     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 644     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 646     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# ...                ...             ...             ...             ...
# 683348  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683686  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683695  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683697  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683699  Not Applicable  Not Applicable  Not Applicable  Not Applicable
#
#               problems root_stone root_grate root_other trunk_wire trnk_light  \
# 37      Not Applicable         No         No         No         No         No
# 239     Not Applicable         No         No         No         No         No
# 641     Not Applicable         No         No         No         No         No
# 644     Not Applicable         No         No         No         No         No
# 646     Not Applicable         No         No         No         No         No
# ...                ...        ...        ...        ...        ...        ...
# 683348  Not Applicable         No         No         No         No         No
# 683686  Not Applicable         No         No         No         No         No
# 683695  Not Applicable         No         No         No         No         No
# 683697  Not Applicable         No         No         No         No         No
# 683699  Not Applicable         No         No         No         No         No
#
#        trnk_other brch_light brch_shoe brch_other
# 37             No         No        No         No
# 239            No         No        No         No
# 641            No         No        No         No
# 644            No         No        No         No
# 646            No         No        No         No
# ...           ...        ...       ...        ...
# 683348         No         No        No         No
# 683686         No         No        No         No
# 683695         No         No        No         No
# 683697         No         No        No         No
# 683699         No         No        No         No
#
# [17654 rows x 20 columns]

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# guards         1
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward guards sidewalk problems root_stone  \
# 32889  Fraxinus pennsylvanica    None   None   Damage     None         No
#
#       root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 32889         No         No         No         No         No         No
#
#       brch_shoe brch_other
# 32889        No         No

# %%
tree_census_subset['problems'].fillna("None",inplace=True)
tree_census_subset['health'].fillna("Good",inplace=True)
tree_census_subset['spc_latin'].fillna("No observation",inplace=True)
tree_census_subset['sidewalk'].fillna("NoDamage",inplace=True)
tree_census_subset['guards'].fillna("None",inplace=True)
# Out:
# C:\Users\IceCandyman\AppData\Local\Temp\ipykernel_5068\3461741088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['problems'].fillna("None",inplace=True)
# C:\Users\IceCandyman\AppData\Local\Temp\ipykernel_5068\3461741088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['health'].fillna("Good",inplace=True)
# C:\Users\IceCandyman\AppData\Local\Temp\ipykernel_5068\3461741088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['spc_latin'].fillna("No observation",inplace=True)
# C:\Users\IceCandyman\AppData\Local\Temp\ipykernel_5068\3461741088.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['sidewalk'].fillna("NoDamage",inplace=True)
# C:\Users\IceCandyman\AppData\Local\Temp\ipykernel_5068\3461741088.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['guards'].fillna("None",inplace=True)

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# guards        0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
big_trees = tree_census_subset[(tree_census_subset['stump_diam']>60) | (tree_census_subset['tree_dbh']>60)]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 2405     168583       425           0          OnCurb  Alive            Good
# 4887     139665        72           0  OffsetFromCurb  Alive            Good
# 6466     166008         0          72          OnCurb  Stump  Not Applicable
# 6724     209349       122           0          OnCurb  Alive            Good
# 7042     206818         0         100          OnCurb  Stump  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 667425   151958        66           0  OffsetFromCurb  Alive            Fair
# 673105   165324        79           0          OnCurb  Alive            Good
# 674016   184879       105           0          OnCurb  Alive            Fair
# 681736   179366       281           0          OnCurb  Alive            Fair
# 682788   183910       127           0          OnCurb   Dead  Not Applicable
#
#                                  spc_latin         steward          guards  \
# 2405                       Quercus bicolor            1or2            None
# 4887                      Acer saccharinum            None            None
# 6466                        Not Applicable  Not Applicable  Not Applicable
# 6724                     Quercus palustris            None            None
# 7042                        Not Applicable  Not Applicable  Not Applicable
# ...                                    ...             ...             ...
# 667425                       Quercus rubra            None            None
# 673105  Gleditsia triacanthos var. inermis            None            None
# 674016                       Ginkgo biloba            None            None
# 681736                   Quercus palustris            None            None
# 682788                      Not Applicable  Not Applicable  Not Applicable
#
#               sidewalk        problems root_stone root_grate root_other  \
# 2405            Damage            None         No         No         No
# 4887          NoDamage            None         No         No         No
# 6466    Not Applicable  Not Applicable         No         No         No
# 6724            Damage            None         No         No         No
# 7042    Not Applicable  Not Applicable         No         No         No
# ...                ...             ...        ...        ...        ...
# 667425        NoDamage            None         No         No         No
# 673105          Damage          Stones        Yes         No         No
# 674016          Damage          Stones        Yes         No         No
# 681736          Damage            None         No         No         No
# 682788  Not Applicable  Not Applicable         No         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 2405           No         No         No         No        No         No
# 4887           No         No         No         No        No         No
# 6466           No         No         No         No        No         No
# 6724           No         No         No         No        No         No
# 7042           No         No         No         No        No         No
# ...           ...        ...        ...        ...       ...        ...
# 667425         No         No         No         No        No         No
# 673105         No         No         No         No        No         No
# 674016         No         No         No         No        No         No
# 681736         No         No         No         No        No         No
# 682788         No         No         No         No        No         No
#
# [245 rows x 20 columns]

# %%
tree_census_subset = tree_census_subset[(tree_census_subset['stump_diam']<=60) & (tree_census_subset['tree_dbh']<=60)]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward guards  sidewalk problems  \
# 0                              Acer rubrum    None   None  NoDamage     None
# 1                        Quercus palustris    None   None    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2   None    Damage     None
# 3       Gleditsia triacanthos var. inermis    None   None    Damage   Stones
# 4                          Tilia americana    None   None    Damage   Stones
# ...                                    ...     ...    ...       ...      ...
# 683783                   Quercus palustris    None   None    Damage     None
# 683784                 Cladrastis kentukea    1or2   None  NoDamage     None
# 683785                         Acer rubrum    None   None    Damage     None
# 683786                         Acer rubrum    None   None  NoDamage     None
# 683787                         Acer rubrum    None   None  NoDamage     None
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 683783         No        No         No
# 683784         No        No         No
# 683785         No        No         No
# 683786         No        No         No
# 683787         No        No         No
#
# [683543 rows x 20 columns]

# %%
tree_census_subset_alive= tree_census_subset[tree_census_subset['status']=='Alive']
tree_census_subset_dead_or_stump = tree_census_subset[(tree_census_subset['status']=='Dead')|(tree_census_subset['status']=='Stump')]

# %%
stats_alive = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin','25%','75%']]
stats_alive
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128   Tsuga canadensis  2.0   7.0
# 129    Ulmus americana  4.0  17.0
# 130   Ulmus parvifolia  3.0  10.0
# 131       Ulmus pumila  4.0  17.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]

# %%
tree_census_subset_alive[tree_census_subset_alive['tree_dbh']==0]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 5312      38793         0           0          OnCurb  Alive   Good
# 30524    204988         0           0          OnCurb  Alive   Good
# 44772    241329         0           0  OffsetFromCurb  Alive   Good
# 47154    173248         0           0          OnCurb  Alive   Good
# 47484    204173         0           0          OnCurb  Alive   Poor
# ...         ...       ...         ...             ...    ...    ...
# 658977   162280         0           0          OnCurb  Alive   Poor
# 671073    17796         0           0          OnCurb  Alive   Fair
# 671971   120612         0           0          OnCurb  Alive   Good
# 672443   116239         0           0          OnCurb  Alive   Good
# 680530    51015         0           0          OnCurb  Alive   Good
#
#                    spc_latin steward   guards  sidewalk problems root_stone  \
# 5312       Cotinus coggygria    3or4  Helpful    Damage     None         No
# 30524        Quercus phellos    1or2     None  NoDamage     None         No
# 44772                  Malus    1or2     None  NoDamage     None         No
# 47154        Quercus bicolor    None     None  NoDamage     None         No
# 47484            Picea abies    None     None  NoDamage     None         No
# ...                      ...     ...      ...       ...      ...        ...
# 658977       Quercus bicolor    None     None    Damage     None         No
# 671073    Taxodium distichum    1or2  Helpful  NoDamage   Stones        Yes
# 671971  Juniperus virginiana    None     None  NoDamage     None         No
# 672443         Acer palmatum    1or2     None  NoDamage     None         No
# 680530         Acer palmatum    1or2     None  NoDamage     None         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 5312           No         No         No         No         No         No
# 30524          No         No         No         No         No         No
# 44772          No         No         No         No         No         No
# 47154          No         No         No         No         No         No
# 47484          No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 658977         No         No         No         No         No         No
# 671073         No         No         No         No         No         No
# 671971         No         No         No         No         No         No
# 672443         No         No         No         No         No         No
# 680530         No         No         No         No         No         No
#
#        brch_shoe brch_other
# 5312          No         No
# 30524         No         No
# 44772         No         No
# 47154         No         No
# 47484         No         No
# ...          ...        ...
# 658977        No         No
# 671073        No         No
# 671971        No         No
# 672443        No         No
# 680530        No         No
#
# [222 rows x 20 columns]

# %%
tree_census_subset_alive = tree_census_subset_alive.merge(stats_alive, on='spc_latin', how='left')
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652018   155433        25           0   OnCurb  Alive   Good
# 652019   183795         7           0   OnCurb  Alive   Good
# 652020   166161        12           0   OnCurb  Alive   Good
# 652021   184028         9           0   OnCurb  Alive   Good
# 652022   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward guards  sidewalk problems  \
# 0                              Acer rubrum    None   None  NoDamage     None
# 1                        Quercus palustris    None   None    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2   None    Damage     None
# 3       Gleditsia triacanthos var. inermis    None   None    Damage   Stones
# 4                          Tilia americana    None   None    Damage   Stones
# ...                                    ...     ...    ...       ...      ...
# 652018                   Quercus palustris    None   None    Damage     None
# 652019                 Cladrastis kentukea    1or2   None  NoDamage     None
# 652020                         Acer rubrum    None   None    Damage     None
# 652021                         Acer rubrum    None   None  NoDamage     None
# 652022                         Acer rubrum    None   None  NoDamage     None
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 652018         No         No         No         No         No         No
# 652019         No         No         No         No         No         No
# 652020         No         No         No         No         No         No
# 652021         No         No         No         No         No         No
# 652022         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other  25%   75%
# 0              No        No         No  5.0  14.0
# 1              No        No         No  8.0  24.0
# 2              No        No         No  6.0  13.0
# 3              No        No         No  6.0  13.0
# 4              No        No         No  4.0  12.0
# ...           ...       ...        ...  ...   ...
# 652018         No        No         No  8.0  24.0
# 652019         No        No         No  3.0   5.0
# 652020         No        No         No  5.0  14.0
# 652021         No        No         No  5.0  14.0
# 652022         No        No         No  5.0  14.0
#
# [652023 rows x 22 columns]

# %%
mask = tree_census_subset_alive['tree_dbh']<tree_census_subset_alive['25%']
tree_census_subset_alive.loc[mask,'tree_dbh'] = tree_census_subset_alive['25%']

mask = tree_census_subset_alive['tree_dbh']>tree_census_subset_alive['75%']
tree_census_subset_alive.loc[mask,'tree_dbh'] = tree_census_subset_alive['75%']

# %%
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652018   155433      24.0           0   OnCurb  Alive   Good
# 652019   183795       5.0           0   OnCurb  Alive   Good
# 652020   166161      12.0           0   OnCurb  Alive   Good
# 652021   184028       9.0           0   OnCurb  Alive   Good
# 652022   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward guards  sidewalk problems  \
# 0                              Acer rubrum    None   None  NoDamage     None
# 1                        Quercus palustris    None   None    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2   None    Damage     None
# 3       Gleditsia triacanthos var. inermis    None   None    Damage   Stones
# 4                          Tilia americana    None   None    Damage   Stones
# ...                                    ...     ...    ...       ...      ...
# 652018                   Quercus palustris    None   None    Damage     None
# 652019                 Cladrastis kentukea    1or2   None  NoDamage     None
# 652020                         Acer rubrum    None   None    Damage     None
# 652021                         Acer rubrum    None   None  NoDamage     None
# 652022                         Acer rubrum    None   None  NoDamage     None
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 652018         No         No         No         No         No         No
# 652019         No         No         No         No         No         No
# 652020         No         No         No         No         No         No
# 652021         No         No         No         No         No         No
# 652022         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other  25%   75%
# 0              No        No         No  5.0  14.0
# 1              No        No         No  8.0  24.0
# 2              No        No         No  6.0  13.0
# 3              No        No         No  6.0  13.0
# 4              No        No         No  4.0  12.0
# ...           ...       ...        ...  ...   ...
# 652018         No        No         No  8.0  24.0
# 652019         No        No         No  3.0   5.0
# 652020         No        No         No  5.0  14.0
# 652021         No        No         No  5.0  14.0
# 652022         No        No         No  5.0  14.0
#
# [652023 rows x 22 columns]
